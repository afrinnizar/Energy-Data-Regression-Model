# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt       #importing numpy pandas matplotlib and seaborn
import seaborn as sns

# %%
 data=pd.read_csv('energy.csv')         #reading the cvs file

# %%
data                                    #calling the dataframe
# Out:
#         X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0     0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1     0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2     0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3     0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4     0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28
# ...    ...    ...    ...     ...  ...  ...  ...  ...    ...    ...
# 1291   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1292   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1293   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1294   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1295   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
#
# [1296 rows x 10 columns]

# %%
df=pd.DataFrame(data)     #converting the data into dataframe

# %%
df                        #calling the dataframe
# Out:
#         X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0     0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1     0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2     0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3     0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4     0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28
# ...    ...    ...    ...     ...  ...  ...  ...  ...    ...    ...
# 1291   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1292   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1293   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1294   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
# 1295   NaN    NaN    NaN     NaN  NaN  NaN  NaN  NaN    NaN    NaN
#
# [1296 rows x 10 columns]

# %%
df.head(5)            #top 5 values from the data set
# Out:
#      X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28

# %%
df.tail(5)           #last 3 values from the data set
# Out:
#       X1  X2  X3  X4  X5  X6  X7  X8  Y1  Y2
# 1291 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1292 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1293 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1294 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1295 NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN

# %%
df.info()        #retreiving the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    float64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    float64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(10)
# memory usage: 101.4 KB

# %% [markdown]
# handling missing values
# --------------------

# %%
df.isnull()         #checking for null values
# Out:
#          X1     X2     X3     X4     X5     X6     X7     X8     Y1     Y2
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1291   True   True   True   True   True   True   True   True   True   True
# 1292   True   True   True   True   True   True   True   True   True   True
# 1293   True   True   True   True   True   True   True   True   True   True
# 1294   True   True   True   True   True   True   True   True   True   True
# 1295   True   True   True   True   True   True   True   True   True   True
#
# [1296 rows x 10 columns]

# %%
df.isnull().sum()      #retrieving the sum of the null values using sum()
# Out:
# X1    528
# X2    528
# X3    528
# X4    528
# X5    528
# X6    528
# X7    528
# X8    528
# Y1    528
# Y2    528
# dtype: int64

# %%
df1=df.dropna()         # dropping NaN VALUES

# %%
df1                     #veiwing the dataframe the df1
# Out:
#        X1     X2     X3      X4   X5   X6   X7   X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0  2.0  0.0  0.0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0  3.0  0.0  0.0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0  4.0  0.0  0.0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0  5.0  0.0  0.0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0  2.0  0.0  0.0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ...  ...  ...    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5  5.0  0.4  5.0  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5  2.0  0.4  5.0  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5  3.0  0.4  5.0  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5  4.0  0.4  5.0  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5  5.0  0.4  5.0  16.64  16.03
#
# [768 rows x 10 columns]

# %%
df1.info()         #checking the information of df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    float64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    float64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(10)
# memory usage: 66.0 KB

# %%
df1.shape            #checking the shape
# Out:
# (768, 10)

# %%
df1.columns        #checking the columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2'], dtype='object')

# %%
df1.describe()       #description of df1
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# ...

# %%
df1.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
df1.duplicated().sum()     #sum of duplicate values
# Out:
# np.int64(0)

# %%
df1=df1.rename(columns={'X1':'relative compactness','X2':'Surface area','X3':'wall area','X4':'roof area',
                       'X5':'overall height','X6':'orientation','X7':'glazing area','X8':'glazing area distribution',
                       'Y1':'heating load','Y2':'Cooling load'})                #renameing the columns

# %%
df1
# Out:
#      relative compactness  Surface area  wall area  roof area  overall height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
# ...

# %%
sns.histplot(df1['heating load'],kde=True,color='red')   #histplot for heating load
# Out:
# <Axes: xlabel='heating load', ylabel='Count'>

# %%
sns.histplot(df1['Cooling load'],kde=True,color='GREEN')   # histplot for cooling load
# Out:
# <Axes: xlabel='Cooling load', ylabel='Count'>

# %%
sns.boxplot(data=df1)     #boxplot for df1
# Out:
# <Axes: >

# %%
c=df1.corr()    #creating corelation

# %%
c
# Out:
#                            relative compactness  Surface area     wall area  \
# relative compactness               1.000000e+00 -9.919015e-01 -2.037817e-01
# Surface area                      -9.919015e-01  1.000000e+00  1.955016e-01
# wall area                         -2.037817e-01  1.955016e-01  1.000000e+00
# roof area                         -8.688234e-01  8.807195e-01 -2.923165e-01
# overall height                     8.277473e-01 -8.581477e-01  2.809757e-01
# orientation                        4.678592e-17 -3.459372e-17 -2.429499e-17
# glazing area                      -2.960552e-15  3.636925e-15 -8.567455e-17
# glazing area distribution         -7.107006e-16  2.438409e-15  2.067384e-16
# heating load                       6.222722e-01 -6.581202e-01  4.556712e-01
# Cooling load                       6.343391e-01 -6.729989e-01  4.271170e-01
#
#                               roof area  overall height   orientation  \
# ...

# %%
plt.figure(figsize=(14,10))
sns.heatmap(c,annot=True,fmt='.2f',cmap='coolwarm')        #heatmap-visualizing co relation
# Out:
# <Axes: >

# %%
df1.skew()        #skweness
# Out:
# relative compactness         0.495513
# Surface area                -0.125131
# wall area                    0.533417
# roof area                   -0.162764
# overall height               0.000000
# orientation                  0.000000
# glazing area                -0.060254
# glazing area distribution   -0.088689
# heating load                 0.360449
# Cooling load                 0.395992
# dtype: float64

# %%
df1
# Out:
#      relative compactness  Surface area  wall area  roof area  overall height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
# ...

# %%
x=df1.drop(columns=['Cooling load'])       #remove the cooling load from df1 and store the rest in x

# %%
x.columns         #viewing the columns in x
# Out:
# Index(['relative compactness', 'Surface area', 'wall area', 'roof area',
#        'overall height', 'orientation', 'glazing area',
#        'glazing area distribution', 'heating load'],
#       dtype='object')

# %%
y=df1['Cooling load']       # store the cooling load columns from df1 in y(target)

# %%
y     #calling y
# Out:
# 0      21.33
# 1      21.33
# 2      21.33
# 3      21.33
# 4      28.28
#        ...
# 763    21.40
# 764    16.88
# 765    17.11
# 766    16.61
# 767    16.03
# Name: Cooling load, Length: 768, dtype: float64

# %%
from sklearn.feature_selection import SelectKBest ,f_regression      # importing sklearn

# %%
sk=SelectKBest(score_func=f_regression,k='all')       #select all features using the f_regression scoring function

# %%
x_new=sk.fit_transform(x,y)              #select all features from x based on y

# %%
selected_columns=x.columns[sk.get_support()]     #get the names of the selected features

# %%
selected_columns        #calling selected columns
# Out:
# Index(['relative compactness', 'Surface area', 'wall area', 'roof area',
#        'overall height', 'orientation', 'glazing area',
#        'glazing area distribution', 'heating load'],
#       dtype='object')

# %%
xselected=x[selected_columns]        #

# %%
featurescore=pd.DataFrame({'features':x.columns,'score':sk.scores_
                          }).sort_values(by='score',ascending=False)         #create a data frame with features names and their score by score

# %%
featurescore      #calling feature score
# Out:
#                     features         score
# 8               heating load  15294.814350
# 4             overall height   3111.127823
# 3                  roof area   2226.031391
# 1               Surface area    634.180214
# 0       relative compactness    515.763924
# 2                  wall area    170.921606
# 6               glazing area     34.466755
# 7  glazing area distribution      1.960440
# 5                orientation      0.156443

# %%
from sklearn.preprocessing import StandardScaler     #importing standard scaler

# %%
ss=StandardScaler()         #setting up the scaler

# %%
xscaled=ss.fit_transform(xselected)        #scaling the selected features

# %%
xscaled                              #viewing the scaled one
# Out:
# array([[ 2.04177671, -1.78587489, -0.56195149, ..., -1.76044698,
#         -1.81457514, -0.67011624],
#        [ 2.04177671, -1.78587489, -0.56195149, ..., -1.76044698,
#         -1.81457514, -0.67011624],
#        [ 2.04177671, -1.78587489, -0.56195149, ..., -1.76044698,
#         -1.81457514, -0.67011624],
#        ...,
#        [-1.36381225,  1.55394308,  1.12390297, ...,  1.2440492 ,
#          1.41133622, -0.58185433],
#        [-1.36381225,  1.55394308,  1.12390297, ...,  1.2440492 ,
#          1.41133622, -0.5778875 ],
#        [-1.36381225,  1.55394308,  1.12390297, ...,  1.2440492 ,
#          1.41133622, -0.56202019]])

# %%
from sklearn.model_selection import train_test_split   #importing train test split

# %%
x_train,x_test,y_train,y_test=train_test_split(xscaled,y,test_size=0.2,random_state=42)    #split the data into train testing set

# %%
print("x_train shape:", x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)      #print the shape of the train and testing test
# Out:
# x_train shape: (614, 9)
# x_test shape: (154, 9)
# y_train shape: (614,)
# y_test shape: (154,)

# %%
from sklearn.linear_model import LinearRegression     #importing the algorithm-------------*linear regression

# %%
LR=LinearRegression()       #create a linear regression object

# %%
LR.fit(x_train,y_train)      #training data
# Out:
# LinearRegression()

# %%
ypred_LR=LR.predict(x_test)       #predicting

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score   #importing mean_absolute_error,mean_squared_error,r2_score

# %%
mae=mean_absolute_error(y_test,ypred_LR)
mse=mean_squared_error(y_test,ypred_LR)
r2=r2_score(y_test,ypred_LR)                                        #evaluating predict values

# %%
print(mae)
print(mse)
print(r2)                                   #displaying the predict values
# Out:
# 1.505552158512221
# 4.160178918056219
# 0.9551014139944851

# %%
from sklearn.svm import SVR   #importing the algorithm------------*SVR*

# %%
svr=SVR()                          #create a SVRegression object

# %%
svr.fit(x_train,y_train)                #teaching
# Out:
# SVR()

# %%
ypred_svr=svr.predict(x_test)      #predicting

# %%
mae=mean_absolute_error(y_test,ypred_svr)
mse=mean_squared_error(y_test,ypred_svr)                                  #evaluating predict values (mean_absolute_error,mean_squared_error,r2_score)
r2=r2_score(y_test,ypred_svr)

# %%
print(mae)
print(mse)                                      #displaying the predicted values
print(r2)
# Out:
# 1.6544206658105338
# 6.67628193423507
# 0.9279464598697176

# %%
from sklearn.tree import DecisionTreeRegressor         #importing DecisionTreeRegressor

# %%
dr=DecisionTreeRegressor()      #create a DecisionTreeRegressor object

# %%
dr.fit(x_train,y_train)        #Teaching
# Out:
# DecisionTreeRegressor()

# %%
ypred_dr=dr.predict(x_test)                    #predicting

# %%
mae=mean_absolute_error(y_test,ypred_dr)
mse=mean_squared_error(y_test,ypred_dr)                           #evaluating predicted values(mean_absolute_error,mean_squared_error,r2_score)
r2=r2_score(y_test,ypred_dr)

# %%
print(mae)
print(mse)                    #displaying the predicted values
print(r2)
# Out:
# 0.9505194805194809
# 3.566016883116885
# 0.9615138870521103
